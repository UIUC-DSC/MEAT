# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.impute import KNNImputer

# %%
agricultural_water_as_a_share_of_total_water_withdrawals = pd.read_csv('agricultural-water-as-a-share-of-total-water-withdrawals.csv')
industrial_water_as_a_share_of_total_water_withdrawals = pd.read_csv('industrial-water-as-a-share-of-total-water-withdrawals.csv')
municipal_water_as_a_share_of_total_water_withdrawals = pd.read_csv('municipal-water-as-a-share-of-total-water-withdrawals.csv')
Annual_Surface_Temperature_Change = pd.read_csv('Annual_Surface_Temperature_Change.csv')
FAOSTAT_meat_production_by_country_by_year = pd.read_csv('FAOSTAT_meat_production_by_country_by_year.csv')
renewable_water_resources_per_capita = pd.read_csv('renewable-water-resources-per-capita.csv')
share_of_population_urban = pd.read_csv('share-of-population-urban.csv')
state_capacity_index = pd.read_csv('state-capacity-index.csv')
WDI_variables = pd.read_csv('WDI_variables.csv')
freshwater_withdrawals_as_a_share_of_internal_resources = pd.read_csv('freshwater-withdrawals-as-a-share-of-internal-resources.csv')

# %%
agricultural_water_as_a_share_of_total_water_withdrawals.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1987
# 1  Afghanistan  AFG  1988
# 2  Afghanistan  AFG  1989
# 3  Afghanistan  AFG  1990
# 4  Afghanistan  AFG  1991
#
#    Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)
# 0                                          99.000046
# 1                                          98.972824
# 2                                          98.944450
# 3                                          98.914856
# 4                                          98.883950

# %%
industrial_water_as_a_share_of_total_water_withdrawals.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1987
# 1  Afghanistan  AFG  1988
# 2  Afghanistan  AFG  1989
# 3  Afghanistan  AFG  1990
# 4  Afghanistan  AFG  1991
#
#    Annual freshwater withdrawals, industry (% of total freshwater withdrawal)
# 0                                           0.000000
# 1                                           0.038641
# 2                                           0.078917
# 3                                           0.120934
# 4                                           0.164809

# %%
municipal_water_as_a_share_of_total_water_withdrawals.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1987
# 1  Afghanistan  AFG  1988
# 2  Afghanistan  AFG  1989
# 3  Afghanistan  AFG  1990
# 4  Afghanistan  AFG  1991
#
#    Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)
# 0                                           0.999958
# 1                                           0.988536
# 2                                           0.976631
# 3                                           0.964212
# 4                                           0.951243

# %%
Annual_Surface_Temperature_Change.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# 2  Food and Agriculture Organization of the Unite...     ECCS
# 3  Food and Agriculture Organization of the Unite...     ECCS
# 4  Food and Agriculture Organization of the Unite...     ECCS
#
#                      CTS_Name  \
# 0  Surface Temperature Change
# 1  Surface Temperature Change
# 2  Surface Temperature Change
# 3  Surface Temperature Change
# 4  Surface Temperature Change
#
#                                  CTS_Full_Descriptor  ...  F2013  F2014  \
# 0  Environment, Climate Change, Climate Indicator...  ...  1.281  0.456
# 1  Environment, Climate Change, Climate Indicator...  ...  1.333  1.198
# 2  Environment, Climate Change, Climate Indicator...  ...  1.192  1.690
# 3  Environment, Climate Change, Climate Indicator...  ...  1.257  1.170
# 4  Environment, Climate Change, Climate Indicator...  ...  0.831  1.946
#
#    F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0  1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1  1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2  1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 3  1.009  1.539  1.435  1.189  1.539  1.430  1.268  1.256
# 4  1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
#
# [5 rows x 72 columns]

# %%
FAOSTAT_meat_production_by_country_by_year.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)         Area  \
# 0         QCL  Crops and livestock products                4  Afghanistan
# 1         QCL  Crops and livestock products                4  Afghanistan
# 2         QCL  Crops and livestock products                4  Afghanistan
# 3         QCL  Crops and livestock products                4  Afghanistan
# 4         QCL  Crops and livestock products                4  Afghanistan
#
#    Element Code                        Element  Item Code (CPC)  \
# 0          5320  Producing Animals/Slaughtered            21151
# 1          5320  Producing Animals/Slaughtered            21151
# 2          5320  Producing Animals/Slaughtered            21151
# 3          5320  Producing Animals/Slaughtered            21151
# 4          5320  Producing Animals/Slaughtered            21151
#
#                                                Item  Year Code  Year Unit  \
# 0  Edible offal of cattle, fresh, chilled or frozen       1961  1961   An
# 1  Edible offal of cattle, fresh, chilled or frozen       1962  1962   An
# 2  Edible offal of cattle, fresh, chilled or frozen       1963  1963   An
# 3  Edible offal of cattle, fresh, chilled or frozen       1964  1964   An
# 4  Edible offal of cattle, fresh, chilled or frozen       1965  1965   An
#
#       Value Flag Flag Description Note
# 0  360000.0    E  Estimated value  NaN
# 1  384000.0    E  Estimated value  NaN
# 2  396000.0    E  Estimated value  NaN
# 3  402000.0    E  Estimated value  NaN
# 4  408000.0    E  Estimated value  NaN

# %%
renewable_water_resources_per_capita.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1962
# 1  Afghanistan  AFG  1963
# 2  Afghanistan  AFG  1964
# 3  Afghanistan  AFG  1965
# 4  Afghanistan  AFG  1966
#
#    Renewable internal freshwater resources per capita (cubic meters)
# 0                                          5256.9688
# 1                                          5148.8047
# 2                                          5039.8086
# 3                                          4929.3545
# 4                                          4819.5127

# %%
share_of_population_urban.head()
# Out:
#         Entity Code  Year  Urban population (% of total population)
# 0  Afghanistan  AFG  1960                                     8.401
# 1  Afghanistan  AFG  1961                                     8.684
# 2  Afghanistan  AFG  1962                                     8.976
# 3  Afghanistan  AFG  1963                                     9.276
# 4  Afghanistan  AFG  1964                                     9.586

# %%
state_capacity_index.head()
# Out:
#         Entity Code  Year  State capacity estimate
# 0  Afghanistan  AFG  1960                   -1.383
# 1  Afghanistan  AFG  1961                   -1.362
# 2  Afghanistan  AFG  1962                   -1.369
# 3  Afghanistan  AFG  1963                   -1.360
# 4  Afghanistan  AFG  1964                   -1.379

# %%
WDI_variables.head()
# Out:
#    Unnamed: 0                 Country Name Country Code  \
# 0          81  Africa Eastern and Southern          AFE
# 1          82  Africa Eastern and Southern          AFE
# 2          83  Africa Eastern and Southern          AFE
# 3          85  Africa Eastern and Southern          AFE
# 4         141  Africa Eastern and Southern          AFE
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS   NaN
# 1  Annual freshwater withdrawals, domestic (% of ...  ER.H2O.FWDM.ZS   NaN
# 2  Annual freshwater withdrawals, industry (% of ...  ER.H2O.FWIN.ZS   NaN
# 3  Annual freshwater withdrawals, total (billion ...  ER.H2O.FWTL.K3   NaN
# 4                      Cereal yield (kg per hectare)  AG.YLD.CREL.KG   NaN
#
#          1961        1962        1963        1964  ...         2014  \
# 0         NaN         NaN         NaN         NaN  ...    83.633270
# 1         NaN         NaN         NaN         NaN  ...    12.008463
# 2         NaN         NaN         NaN         NaN  ...     4.369645
# 3         NaN         NaN         NaN         NaN  ...    92.689935
# 4  924.111737  931.506715  934.015106  879.750864  ...  1653.295813
#
#           2015         2016         2017         2018         2019  \
# 0    82.964750    83.359745    83.226519    82.852077    83.350418
# 1    11.677217    10.818819    10.806661     9.976818    10.333224
# 2     5.368647     5.819470     5.966820     5.850732     6.306158
# 3    95.156360    96.659279    96.930950    97.640204    98.037076
# 4  1639.943870  1510.042711  1771.175828  1737.643458  1727.181531
#
#           2020         2021         2022  Unnamed: 67
# 0    83.608959          NaN          NaN          NaN
# 1    10.277311          NaN          NaN          NaN
# 2     6.113730          NaN          NaN          NaN
# 3    98.377503          NaN          NaN          NaN
# 4  1864.028459  1923.422312  1841.858488          NaN
#
# [5 rows x 69 columns]

# %%
freshwater_withdrawals_as_a_share_of_internal_resources.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2000
# 1  Afghanistan  AFG  2001
# 2  Afghanistan  AFG  2002
# 3  Afghanistan  AFG  2003
# 4  Afghanistan  AFG  2004
#
#    6.4.2 - Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%) - ER_H2O_STRESS - No breakdown
# 0                                              54.76
# 1                                              54.76
# 2                                              54.76
# 3                                              54.76
# 4                                              54.76

# %%
temp1 = pd.merge(left = agricultural_water_as_a_share_of_total_water_withdrawals,
                 left_on = ['Code', 'Entity', 'Year'],
                 right = industrial_water_as_a_share_of_total_water_withdrawals,
                 right_on = ['Code', 'Entity', 'Year'],
                 how = 'inner')

# %%
temp2 = pd.merge(left = temp1,
                 left_on = ['Code', 'Entity', 'Year'],
                 right = municipal_water_as_a_share_of_total_water_withdrawals,
                 right_on = ['Code', 'Entity', 'Year'],
                 how = 'inner')

# %%
temp3 = pd.merge(left = temp2,
                 left_on = ['Code', 'Entity', 'Year'],
                 right = renewable_water_resources_per_capita,
                 right_on = ['Code', 'Entity', 'Year'],
                 how = 'inner')

# %%
temp4 = pd.merge(left = temp3,
                 left_on = ['Code', 'Entity', 'Year'],
                 right = share_of_population_urban,
                 right_on = ['Code', 'Entity', 'Year'],
                 how = 'inner')

# %%
temp5 = pd.merge(left = temp4,
                 left_on = ['Code', 'Entity', 'Year'],
                 right = state_capacity_index,
                 right_on = ['Code', 'Entity', 'Year'],
                 how = 'inner')

# %%
temp6 = pd.merge(left = temp5,
                 left_on = ['Code', 'Entity', 'Year'],
                 right = freshwater_withdrawals_as_a_share_of_internal_resources,
                 right_on = ['Code', 'Entity', 'Year'],
                 how = 'inner')

# %%
temp6[~temp6['Entity'].isin(FAOSTAT_meat_production_by_country_by_year['Area'])].head(n = 458)
# Out:
#        Entity      Code  Year  \
# 207   Bolivia       BOL  2000
# 208   Bolivia       BOL  2001
# 209   Bolivia       BOL  2002
# 210   Bolivia       BOL  2003
# 211   Bolivia       BOL  2004
# ...       ...       ...   ...
# 2360  Vietnam       VNM  2012
# 2361  Vietnam       VNM  2013
# 2362  Vietnam       VNM  2014
# 2363  Vietnam       VNM  2015
# 2364    World  OWID_WRL  2015
#
#       Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)  \
# 207                                           91.090390
# 208                                           91.199340
# 209                                           91.306656
# 210                                           91.412360
# 211                                           91.516495
# ...                                                 ...
# 2360                                          94.782394
# 2361                                          94.782394
# 2362                                          94.782394
# 2363                                          94.782394
# 2364                                          71.808110
#
#       Annual freshwater withdrawals, industry (% of total freshwater withdrawal)  \
# 207                                            2.249342
# 208                                            2.163495
# 209                                            2.078942
# 210                                            1.995656
# 211                                            1.913606
# ...                                                 ...
# 2360                                           3.747410
# 2361                                           3.747410
# 2362                                           3.747410
# 2363                                           3.747410
# 2364                                          16.336153
#
#       Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)  \
# 207                                            6.660269
# 208                                            6.637161
# 209                                            6.614402
# 210                                            6.591984
# 211                                            6.569899
# ...                                                 ...
# 2360                                           1.470194
# 2361                                           1.470194
# 2362                                           1.470194
# 2363                                           1.470194
# 2364                                          11.836247
#
#       Renewable internal freshwater resources per capita (cubic meters)  \
# 207                                          35320.8600
# 208                                          34701.2460
# 209                                          34098.8900
# 210                                          33508.5940
# 211                                          32930.8600
# ...                                                 ...
# 2360                                          4024.8003
# 2361                                          3981.7104
# 2362                                          3939.4750
# 2363                                          3898.6284
# 2364                                          5809.7030
#
#       Urban population (% of total population)  State capacity estimate  \
# 207                                  61.787000                 0.226100
# 208                                  62.306000                 0.207000
# 209                                  62.783000                 0.193500
# 210                                  63.248000                 0.168000
# 211                                  63.711000                 0.221400
# ...                                        ...                      ...
# 2360                                 31.752000                 0.583100
# 2361                                 32.429000                 0.692200
# 2362                                 33.115000                 0.648000
# 2363                                 33.809000                 0.755700
# 2364                                 53.831387                 0.664639
#
#       6.4.2 - Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%) - ER_H2O_STRESS - No breakdown
# 207                                                1.11
# 208                                                1.12
# 209                                                1.13
# 210                                                1.13
# 211                                                1.14
# ...                                                 ...
# 2360                                              18.13
# 2361                                              18.13
# 2362                                              18.13
# 2363                                              18.13
# 2364                                              18.03
#
# [295 rows x 10 columns]

# %%
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Bolivia (Plurinational State of)', 'Bolivia')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Cabo Verde', 'Cape Verde')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace("Côte d'Ivoire", "Cote d'Ivoire")
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Democratic Republic of the Congo', 'Democratic Republic of Congo')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Timor-Leste', 'East Timor')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Iran (Islamic Republic of)', 'Iran')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace("Lao People's Democratic Republic", 'Laos')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Republic of Moldova', 'Moldova')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Netherlands (Kingdom of the)', 'Netherlands')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace("Democratic People's Republic of Korea", 'North Korea')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Russian Federation', 'Russia')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Republic of Korea', 'South Korea')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Syrian Arab Republic', 'Syria')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('United Republic of Tanzania', 'Tanzania')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Türkiye', 'Turkey')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('United Kingdom of Great Britain and Northern Ireland', 'United Kingdom')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('United States of America', 'United States')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Venezuela (Bolivarian Republic of)', 'Venezuela')
FAOSTAT_meat_production_by_country_by_year['Area'] = FAOSTAT_meat_production_by_country_by_year['Area'].replace('Viet Nam', 'Vietnam')

# %%
temp7 = pd.merge(left = temp6,
                 left_on = ['Entity', 'Year'],
                 right = FAOSTAT_meat_production_by_country_by_year,
                 right_on = ['Area', 'Year'],
                 how = 'inner')[['Entity',
                                 'Code',
                                 'Year',
                                 '6.4.2 - Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%) - ER_H2O_STRESS - No breakdown',
                                 'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
                                 'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
                                 'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
                                 'Renewable internal freshwater resources per capita (cubic meters)',
                                 'Urban population (% of total population)',
                                 'State capacity estimate',
                                 'Value'
                                 ]]
temp7.rename(columns={'6.4.2 - Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%) - ER_H2O_STRESS - No breakdown':'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)', 'Value': 'Cattle Production'}, inplace=True)

# %%
temp7
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2000
# 1     Afghanistan  AFG  2001
# 2     Afghanistan  AFG  2002
# 3     Afghanistan  AFG  2003
# 4     Afghanistan  AFG  2004
# ...           ...  ...   ...
# 2391     Zimbabwe  ZWE  2011
# 2392     Zimbabwe  ZWE  2012
# 2393     Zimbabwe  ZWE  2013
# 2394     Zimbabwe  ZWE  2014
# 2395     Zimbabwe  ZWE  2015
#
#       Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)  \
# 0                                                 54.76
# 1                                                 54.76
# 2                                                 54.76
# 3                                                 54.76
# 4                                                 54.76
# ...                                                 ...
# 2391                                              32.70
# 2392                                              32.49
# 2393                                              32.28
# 2394                                              32.08
# 2395                                              31.87
#
#       Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)  \
# 0                                             98.606200
# 1                                             98.518580
# 2                                             98.431110
# 3                                             98.343796
# 4                                             98.256630
# ...                                                 ...
# 2391                                          80.580560
# 2392                                          80.195750
# 2393                                          79.806060
# 2394                                          79.411410
# 2395                                          79.011690
#
#       Annual freshwater withdrawals, industry (% of total freshwater withdrawal)  \
# 0                                              0.633545
# 1                                              0.673374
# 2                                              0.713133
# 3                                              0.752822
# 4                                              0.792440
# ...                                                 ...
# 2391                                           4.255136
# 2392                                           3.799411
# 2393                                           3.337913
# 2394                                           2.870530
# 2395                                           2.397149
#
#       Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)  \
# 0                                              0.760254
# 1                                              0.808049
# 2                                              0.855760
# 3                                              0.903386
# 4                                              0.950928
# ...                                                 ...
# 2391                                          15.164305
# 2392                                          16.004839
# 2393                                          16.856024
# 2394                                          17.718060
# 2395                                          18.591160
#
#       Renewable internal freshwater resources per capita (cubic meters)  \
# 0                                             2412.6309
# 1                                             2394.7830
# 2                                             2245.2107
# 3                                             2082.1255
# 4                                             2001.8213
# ...                                                 ...
# 2391                                           941.2101
# 2392                                           924.2136
# 2393                                           904.4351
# 2394                                           884.8310
# 2395                                           866.1289
#
#       Urban population (% of total population)  State capacity estimate  \
# 0                                       22.078                 -1.18400
# 1                                       22.169                 -1.28100
# 2                                       22.261                 -1.33200
# 3                                       22.353                 -1.80300
# 4                                       22.500                 -1.82600
# ...                                        ...                      ...
# 2391                                    33.015                  0.03609
# 2392                                    32.834                  0.08874
# 2393                                    32.654                  0.05633
# 2394                                    32.504                  0.26540
# 2395                                    32.385                  0.29650
#
#       Cattle Production
# 0             700000.00
# 1             600000.00
# 2             833000.00
# 3             761000.00
# 4             829000.00
# ...                 ...
# 2391         3060942.49
# 2392         3069409.87
# 2393         3072585.53
# 2394         2500000.00
# 2395         2600000.00
#
# [2396 rows x 11 columns]

# %%
df = pd.read_csv('WDI_variables.csv')
df.head()
# Out:
#    Unnamed: 0                 Country Name Country Code  \
# 0          81  Africa Eastern and Southern          AFE
# 1          82  Africa Eastern and Southern          AFE
# 2          83  Africa Eastern and Southern          AFE
# 3          85  Africa Eastern and Southern          AFE
# 4         141  Africa Eastern and Southern          AFE
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS   NaN
# 1  Annual freshwater withdrawals, domestic (% of ...  ER.H2O.FWDM.ZS   NaN
# 2  Annual freshwater withdrawals, industry (% of ...  ER.H2O.FWIN.ZS   NaN
# 3  Annual freshwater withdrawals, total (billion ...  ER.H2O.FWTL.K3   NaN
# 4                      Cereal yield (kg per hectare)  AG.YLD.CREL.KG   NaN
#
#          1961        1962        1963        1964  ...         2014  \
# 0         NaN         NaN         NaN         NaN  ...    83.633270
# 1         NaN         NaN         NaN         NaN  ...    12.008463
# 2         NaN         NaN         NaN         NaN  ...     4.369645
# 3         NaN         NaN         NaN         NaN  ...    92.689935
# 4  924.111737  931.506715  934.015106  879.750864  ...  1653.295813
#
#           2015         2016         2017         2018         2019  \
# 0    82.964750    83.359745    83.226519    82.852077    83.350418
# 1    11.677217    10.818819    10.806661     9.976818    10.333224
# 2     5.368647     5.819470     5.966820     5.850732     6.306158
# 3    95.156360    96.659279    96.930950    97.640204    98.037076
# 4  1639.943870  1510.042711  1771.175828  1737.643458  1727.181531
#
#           2020         2021         2022  Unnamed: 67
# 0    83.608959          NaN          NaN          NaN
# 1    10.277311          NaN          NaN          NaN
# 2     6.113730          NaN          NaN          NaN
# 3    98.377503          NaN          NaN          NaN
# 4  1864.028459  1923.422312  1841.858488          NaN
#
# [5 rows x 69 columns]

# %%
melted_df = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Indicator Name'], var_name='Year', value_name='Value')

# Convert 'Value' column to numeric, ignoring errors for non-numeric values
melted_df['Value'] = pd.to_numeric(melted_df['Value'], errors='coerce')

# Pivot the melted DataFrame to get the desired structure
pivoted_df = melted_df.pivot_table(index=['Country Name', 'Country Code', 'Year'], columns='Indicator Name', values='Value').reset_index()
pivoted_df.replace('Unnamed: 0', np.nan, inplace=True)
pivoted_df = pivoted_df.fillna(value = 0)
pivoted_df['Year'] = pivoted_df['Year'].astype('int64')
pivoted_df = pivoted_df[pivoted_df['Year'] != 0]
pivoted_df = pivoted_df[['Country Name',
                         'Year',
                         'Annual freshwater withdrawals, total (billion cubic meters)',
                         'Cereal yield (kg per hectare)', 'Control of Corruption: Estimate',
                         'Electricity production from hydroelectric sources (% of total)',
                         'Permanent cropland (% of land area)',
                         'Population density (people per sq. km of land area)'
                         ]]

# %%
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Cabo Verde', 'Cape Verde')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Congo, Rep.', 'Congo')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Congo, Dem. Rep.', 'Democratic Republic of Congo')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Timor-Leste', 'East Timor')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Egypt, Arab Rep.', 'Egypt')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Gambia, The', 'Gambia')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Iran, Islamic Rep.', 'Iran')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Kyrgyz Republic', 'Kyrgyzstan')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Lao PDR', 'Laos')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace("Korea, Dem. People's Rep.", 'North Korea')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Korea, Rep.', 'South Korea')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Russian Federation', 'Russia')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Slovak Republic', 'Slovakia')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Syrian Arab Republic', 'Syria')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Turkiye', 'Turkey')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Venezuela, RB', 'Venezuela')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Viet Nam', 'Vietnam')
pivoted_df['Country Name'] = pivoted_df['Country Name'].replace('Yemen, Rep.', 'Yemen')

# %%
df_final = pd.merge(left = temp7,
                    left_on = ['Entity', 'Year'],
                    right = pivoted_df,
                    right_on = ['Country Name', 'Year'],
                    how = 'inner')[['Entity',
                                    'Code',
                                    'Year',
                                    'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)',
                                    'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
                                    'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
                                    'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
                                    'Renewable internal freshwater resources per capita (cubic meters)',
                                    'Urban population (% of total population)',
                                    'State capacity estimate',
                                    'Cattle Production',
                                    'Annual freshwater withdrawals, total (billion cubic meters)',
                                    'Cereal yield (kg per hectare)', 'Control of Corruption: Estimate',
                                    'Electricity production from hydroelectric sources (% of total)',
                                    'Permanent cropland (% of land area)',
                                    'Population density (people per sq. km of land area)'
                                    ]]

# %%
df_final
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2000
# 1     Afghanistan  AFG  2001
# 2     Afghanistan  AFG  2002
# 3     Afghanistan  AFG  2003
# 4     Afghanistan  AFG  2004
# ...           ...  ...   ...
# 2391     Zimbabwe  ZWE  2011
# 2392     Zimbabwe  ZWE  2012
# 2393     Zimbabwe  ZWE  2013
# 2394     Zimbabwe  ZWE  2014
# 2395     Zimbabwe  ZWE  2015
#
#       Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)  \
# 0                                                 54.76
# 1                                                 54.76
# 2                                                 54.76
# 3                                                 54.76
# 4                                                 54.76
# ...                                                 ...
# 2391                                              32.70
# 2392                                              32.49
# 2393                                              32.28
# 2394                                              32.08
# 2395                                              31.87
#
#       Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)  \
# 0                                             98.606200
# 1                                             98.518580
# 2                                             98.431110
# 3                                             98.343796
# 4                                             98.256630
# ...                                                 ...
# 2391                                          80.580560
# 2392                                          80.195750
# 2393                                          79.806060
# 2394                                          79.411410
# 2395                                          79.011690
#
#       Annual freshwater withdrawals, industry (% of total freshwater withdrawal)  \
# 0                                              0.633545
# 1                                              0.673374
# 2                                              0.713133
# 3                                              0.752822
# 4                                              0.792440
# ...                                                 ...
# 2391                                           4.255136
# 2392                                           3.799411
# 2393                                           3.337913
# 2394                                           2.870530
# 2395                                           2.397149
#
#       Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)  \
# 0                                              0.760254
# 1                                              0.808049
# 2                                              0.855760
# 3                                              0.903386
# 4                                              0.950928
# ...                                                 ...
# 2391                                          15.164305
# 2392                                          16.004839
# 2393                                          16.856024
# 2394                                          17.718060
# 2395                                          18.591160
#
#       Renewable internal freshwater resources per capita (cubic meters)  \
# 0                                             2412.6309
# 1                                             2394.7830
# 2                                             2245.2107
# 3                                             2082.1255
# 4                                             2001.8213
# ...                                                 ...
# 2391                                           941.2101
# 2392                                           924.2136
# 2393                                           904.4351
# 2394                                           884.8310
# 2395                                           866.1289
#
#       Urban population (% of total population)  State capacity estimate  \
# 0                                       22.078                 -1.18400
# 1                                       22.169                 -1.28100
# 2                                       22.261                 -1.33200
# 3                                       22.353                 -1.80300
# 4                                       22.500                 -1.82600
# ...                                        ...                      ...
# 2391                                    33.015                  0.03609
# 2392                                    32.834                  0.08874
# 2393                                    32.654                  0.05633
# 2394                                    32.504                  0.26540
# 2395                                    32.385                  0.29650
#
#       Cattle Production  \
# 0             700000.00
# 1             600000.00
# 2             833000.00
# 3             761000.00
# 4             829000.00
# ...                 ...
# 2391         3060942.49
# 2392         3069409.87
# 2393         3072585.53
# 2394         2500000.00
# 2395         2600000.00
#
#       Annual freshwater withdrawals, total (billion cubic meters)  \
# 0                                             20.282000
# 1                                             20.282000
# 2                                             20.282000
# 3                                             20.282000
# 4                                             20.282000
# ...                                                 ...
# 2391                                           3.482850
# 2392                                           3.460625
# 2393                                           3.438750
# 2394                                           3.416875
# 2395                                           3.395000
#
#       Cereal yield (kg per hectare)  Control of Corruption: Estimate  \
# 0                             806.3                        -1.271724
# 1                            1006.7                         0.000000
# 2                            1669.8                        -1.251137
# 3                            1458.0                        -1.344180
# 4                            1334.8                        -1.350647
# ...                             ...                              ...
# 2391                          587.4                        -1.425627
# 2392                          695.7                        -1.381803
# 2393                          668.5                        -1.419667
# 2394                          831.4                        -1.404367
# 2395                          557.5                        -1.337617
#
#       Electricity production from hydroelectric sources (% of total)  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 2391                                          56.434462
# 2392                                          58.567858
# 2393                                          52.204807
# 2394                                          54.169160
# 2395                                          51.395612
#
#       Permanent cropland (% of land area)  \
# 0                                0.170185
# 1                                0.171719
# 2                                0.171719
# 3                                0.171719
# 4                                0.171719
# ...                                   ...
# 2391                             0.258498
# 2392                             0.258498
# 2393                             0.258498
# 2394                             0.258498
# 2395                             0.258498
#
#       Population density (people per sq. km of land area)
# 0                                             29.963329
# 1                                             30.186640
# 2                                             32.197624
# 3                                             34.719547
# 4                                             36.112339
# ...                                                 ...
# 2391                                          33.671410
# 2392                                          34.290632
# 2393                                          35.040512
# 2394                                          35.816862
# 2395                                          36.590247
#
# [2396 rows x 17 columns]

# %%
df_final.replace(0, np.nan, inplace=True)

# %%
df_final.to_csv('water_stress.csv')

# %%
df_final.dropna().shape[0]
# Out:
# 1568

# %%
df3 = df_final.dropna().groupby(by = 'Entity')[['Annual freshwater withdrawals, total (billion cubic meters)',
                                                'Cereal yield (kg per hectare)', 'Control of Corruption: Estimate',
                                                'Electricity production from hydroelectric sources (% of total)',
                                                'Permanent cropland (% of land area)',
                                                'Population density (people per sq. km of land area)']].std() / df_final.dropna().groupby(by = 'Entity')[['Annual freshwater withdrawals, total (billion cubic meters)',
                                                'Cereal yield (kg per hectare)', 'Control of Corruption: Estimate',
                                                'Electricity production from hydroelectric sources (% of total)',
                                                'Permanent cropland (% of land area)',
                                                'Population density (people per sq. km of land area)'
                                                ]].mean()
df3.median()
# Out:
# Annual freshwater withdrawals, total (billion cubic meters)       0.070450
# Cereal yield (kg per hectare)                                     0.112977
# Control of Corruption: Estimate                                  -0.099972
# Electricity production from hydroelectric sources (% of total)    0.176460
# Permanent cropland (% of land area)                               0.091741
# Population density (people per sq. km of land area)               0.047343
# dtype: float64

# %%
sns.heatmap(df_final[['Year',
                      'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)',
                      'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
                      'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
                      'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
                      'Renewable internal freshwater resources per capita (cubic meters)',
                      'Urban population (% of total population)',
                      'State capacity estimate',
                      'Cattle Production',
                      'Annual freshwater withdrawals, total (billion cubic meters)',
                      'Cereal yield (kg per hectare)', 'Control of Corruption: Estimate',
                      'Electricity production from hydroelectric sources (% of total)',
                      'Permanent cropland (% of land area)',
                      'Population density (people per sq. km of land area)'
                      ]].corr(), vmin = -1, vmax = 1, cmap = 'RdBu')
# Out:
# <Axes: >

# %%
df_final[['Year',
          'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)',
          'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
          'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
          'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
          'Renewable internal freshwater resources per capita (cubic meters)',
          'Urban population (% of total population)',
          'State capacity estimate',
          'Cattle Production',
          'Annual freshwater withdrawals, total (billion cubic meters)',
          'Cereal yield (kg per hectare)', 'Control of Corruption: Estimate',
          'Electricity production from hydroelectric sources (% of total)',
          'Permanent cropland (% of land area)',
          'Population density (people per sq. km of land area)'
          ]].corr()
# Out:
#                                                         Year  \
# Year                                                1.000000
# Level of water stress: freshwater withdrawal as...  0.003839
# Annual freshwater withdrawals, agriculture (% o...  0.005764
# Annual freshwater withdrawals, industry (% of t... -0.017203
# Annual freshwater withdrawals, domestic (% of t...  0.011115
# Renewable internal freshwater resources per cap... -0.015685
# Urban population (% of total population)            0.052643
# State capacity estimate                             0.049277
# Cattle Production                                   0.001131
# Annual freshwater withdrawals, total (billion c... -0.000098
# Cereal yield (kg per hectare)                       0.097590
# Control of Corruption: Estimate                    -0.016555
# Electricity production from hydroelectric sourc... -0.021416
# Permanent cropland (% of land area)                 0.020454
# Population density (people per sq. km of land a...  0.020145
#
#                                                     Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)  \
# Year                                                                                         0.003839
# Level of water stress: freshwater withdrawal as...                                           1.000000
# Annual freshwater withdrawals, agriculture (% o...                                           0.079351
# Annual freshwater withdrawals, industry (% of t...                                          -0.125090
# Annual freshwater withdrawals, domestic (% of t...                                           0.021418
# Renewable internal freshwater resources per cap...                                          -0.111642
# Urban population (% of total population)                                                     0.253811
# State capacity estimate                                                                     -0.020013
# Cattle Production                                                                           -0.052501
# Annual freshwater withdrawals, total (billion c...                                          -0.016563
# Cereal yield (kg per hectare)                                                                0.492529
# Control of Corruption: Estimate                                                              0.072461
# Electricity production from hydroelectric sourc...                                          -0.344789
# Permanent cropland (% of land area)                                                         -0.085238
# Population density (people per sq. km of land a...                                           0.060092
#
#                                                     Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)  \
# Year                                                                                         0.005764
# Level of water stress: freshwater withdrawal as...                                           0.079351
# Annual freshwater withdrawals, agriculture (% o...                                           1.000000
# Annual freshwater withdrawals, industry (% of t...                                          -0.802074
# Annual freshwater withdrawals, domestic (% of t...                                          -0.659716
# Renewable internal freshwater resources per cap...                                          -0.012209
# Urban population (% of total population)                                                    -0.320496
# State capacity estimate                                                                     -0.396439
# Cattle Production                                                                           -0.002047
# Annual freshwater withdrawals, total (billion c...                                           0.123034
# Cereal yield (kg per hectare)                                                               -0.167470
# Control of Corruption: Estimate                                                             -0.392270
# Electricity production from hydroelectric sourc...                                           0.181054
# Permanent cropland (% of land area)                                                          0.113202
# Population density (people per sq. km of land a...                                          -0.145916
#
#                                                     Annual freshwater withdrawals, industry (% of total freshwater withdrawal)  \
# Year                                                                                        -0.017203
# Level of water stress: freshwater withdrawal as...                                          -0.125090
# Annual freshwater withdrawals, agriculture (% o...                                          -0.802074
# Annual freshwater withdrawals, industry (% of t...                                           1.000000
# Annual freshwater withdrawals, domestic (% of t...                                           0.082980
# Renewable internal freshwater resources per cap...                                           0.002190
# Urban population (% of total population)                                                     0.309522
# State capacity estimate                                                                      0.514116
# Cattle Production                                                                            0.087164
# Annual freshwater withdrawals, total (billion c...                                          -0.007180
# Cereal yield (kg per hectare)                                                                0.217361
# Control of Corruption: Estimate                                                              0.433859
# Electricity production from hydroelectric sourc...                                          -0.260278
# Permanent cropland (% of land area)                                                         -0.127054
# Population density (people per sq. km of land a...                                           0.104309
#
#                                                     Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)  \
# Year                                                                                         0.011115
# Level of water stress: freshwater withdrawal as...                                           0.021418
# Annual freshwater withdrawals, agriculture (% o...                                          -0.659716
# Annual freshwater withdrawals, industry (% of t...                                           0.082980
# Annual freshwater withdrawals, domestic (% of t...                                           1.000000
# Renewable internal freshwater resources per cap...                                           0.014788
# Urban population (% of total population)                                                     0.149275
# State capacity estimate                                                                      0.013058
# Cattle Production                                                                           -0.104461
# Annual freshwater withdrawals, total (billion c...                                          -0.192823
# Cereal yield (kg per hectare)                                                                0.002279
# Control of Corruption: Estimate                                                              0.105266
# Electricity production from hydroelectric sourc...                                           0.068682
# Permanent cropland (% of land area)                                                         -0.034167
# Population density (people per sq. km of land a...                                           0.108866
#
#                                                     Renewable internal freshwater resources per capita (cubic meters)  \
# Year                                                                                        -0.015685
# Level of water stress: freshwater withdrawal as...                                          -0.111642
# Annual freshwater withdrawals, agriculture (% o...                                          -0.012209
# Annual freshwater withdrawals, industry (% of t...                                           0.002190
# Annual freshwater withdrawals, domestic (% of t...                                           0.014788
# Renewable internal freshwater resources per cap...                                           1.000000
# Urban population (% of total population)                                                     0.000673
# State capacity estimate                                                                     -0.005475
# Cattle Production                                                                           -0.009625
# Annual freshwater withdrawals, total (billion c...                                          -0.063636
# Cereal yield (kg per hectare)                                                                0.052420
# Control of Corruption: Estimate                                                              0.040956
# Electricity production from hydroelectric sourc...                                           0.367712
# Permanent cropland (% of land area)                                                         -0.144745
# Population density (people per sq. km of land a...                                          -0.090851
#
#                                                     Urban population (% of total population)  \
# Year                                                                                0.052643
# Level of water stress: freshwater withdrawal as...                                  0.253811
# Annual freshwater withdrawals, agriculture (% o...                                 -0.320496
# Annual freshwater withdrawals, industry (% of t...                                  0.309522
# Annual freshwater withdrawals, domestic (% of t...                                  0.149275
# Renewable internal freshwater resources per cap...                                  0.000673
# Urban population (% of total population)                                            1.000000
# State capacity estimate                                                             0.606259
# Cattle Production                                                                   0.155313
# Annual freshwater withdrawals, total (billion c...                                 -0.022233
# Cereal yield (kg per hectare)                                                       0.434378
# Control of Corruption: Estimate                                                     0.571320
# Electricity production from hydroelectric sourc...                                 -0.309839
# Permanent cropland (% of land area)                                                -0.185562
# Population density (people per sq. km of land a...                                  0.173087
#
#                                                     State capacity estimate  \
# Year                                                               0.049277
# Level of water stress: freshwater withdrawal as...                -0.020013
# Annual freshwater withdrawals, agriculture (% o...                -0.396439
# Annual freshwater withdrawals, industry (% of t...                 0.514116
# Annual freshwater withdrawals, domestic (% of t...                 0.013058
# Renewable internal freshwater resources per cap...                -0.005475
# Urban population (% of total population)                           0.606259
# State capacity estimate                                            1.000000
# Cattle Production                                                  0.166065
# Annual freshwater withdrawals, total (billion c...                 0.100647
# Cereal yield (kg per hectare)                                      0.483618
# Control of Corruption: Estimate                                    0.856510
# Electricity production from hydroelectric sourc...                -0.327152
# Permanent cropland (% of land area)                               -0.137571
# Population density (people per sq. km of land a...                 0.122687
#
#                                                     Cattle Production  \
# Year                                                         0.001131
# Level of water stress: freshwater withdrawal as...          -0.052501
# Annual freshwater withdrawals, agriculture (% o...          -0.002047
# Annual freshwater withdrawals, industry (% of t...           0.087164
# Annual freshwater withdrawals, domestic (% of t...          -0.104461
# Renewable internal freshwater resources per cap...          -0.009625
# Urban population (% of total population)                     0.155313
# State capacity estimate                                      0.166065
# Cattle Production                                            1.000000
# Annual freshwater withdrawals, total (billion c...           0.770594
# Cereal yield (kg per hectare)                                0.136190
# Control of Corruption: Estimate                              0.086649
# Electricity production from hydroelectric sourc...          -0.017308
# Permanent cropland (% of land area)                         -0.104887
# Population density (people per sq. km of land a...          -0.045118
#
#                                                     Annual freshwater withdrawals, total (billion cubic meters)  \
# Year                                                                                        -0.000098
# Level of water stress: freshwater withdrawal as...                                          -0.016563
# Annual freshwater withdrawals, agriculture (% o...                                           0.123034
# Annual freshwater withdrawals, industry (% of t...                                          -0.007180
# Annual freshwater withdrawals, domestic (% of t...                                          -0.192823
# Renewable internal freshwater resources per cap...                                          -0.063636
# Urban population (% of total population)                                                    -0.022233
# State capacity estimate                                                                      0.100647
# Cattle Production                                                                            0.770594
# Annual freshwater withdrawals, total (billion c...                                           1.000000
# Cereal yield (kg per hectare)                                                                0.121041
# Control of Corruption: Estimate                                                              0.011467
# Electricity production from hydroelectric sourc...                                          -0.152970
# Permanent cropland (% of land area)                                                         -0.008504
# Population density (people per sq. km of land a...                                           0.007717
#
#                                                     Cereal yield (kg per hectare)  \
# Year                                                                     0.097590
# Level of water stress: freshwater withdrawal as...                       0.492529
# Annual freshwater withdrawals, agriculture (% o...                      -0.167470
# Annual freshwater withdrawals, industry (% of t...                       0.217361
# Annual freshwater withdrawals, domestic (% of t...                       0.002279
# Renewable internal freshwater resources per cap...                       0.052420
# Urban population (% of total population)                                 0.434378
# State capacity estimate                                                  0.483618
# Cattle Production                                                        0.136190
# Annual freshwater withdrawals, total (billion c...                       0.121041
# Cereal yield (kg per hectare)                                            1.000000
# Control of Corruption: Estimate                                          0.484050
# Electricity production from hydroelectric sourc...                      -0.295003
# Permanent cropland (% of land area)                                     -0.086527
# Population density (people per sq. km of land a...                       0.215995
#
#                                                     Control of Corruption: Estimate  \
# Year                                                                      -0.016555
# Level of water stress: freshwater withdrawal as...                         0.072461
# Annual freshwater withdrawals, agriculture (% o...                        -0.392270
# Annual freshwater withdrawals, industry (% of t...                         0.433859
# Annual freshwater withdrawals, domestic (% of t...                         0.105266
# Renewable internal freshwater resources per cap...                         0.040956
# Urban population (% of total population)                                   0.571320
# State capacity estimate                                                    0.856510
# Cattle Production                                                          0.086649
# Annual freshwater withdrawals, total (billion c...                         0.011467
# Cereal yield (kg per hectare)                                              0.484050
# Control of Corruption: Estimate                                            1.000000
# Electricity production from hydroelectric sourc...                        -0.220109
# Permanent cropland (% of land area)                                       -0.147713
# Population density (people per sq. km of land a...                         0.211179
#
#                                                     Electricity production from hydroelectric sources (% of total)  \
# Year                                                                                        -0.021416
# Level of water stress: freshwater withdrawal as...                                          -0.344789
# Annual freshwater withdrawals, agriculture (% o...                                           0.181054
# Annual freshwater withdrawals, industry (% of t...                                          -0.260278
# Annual freshwater withdrawals, domestic (% of t...                                           0.068682
# Renewable internal freshwater resources per cap...                                           0.367712
# Urban population (% of total population)                                                    -0.309839
# State capacity estimate                                                                     -0.327152
# Cattle Production                                                                           -0.017308
# Annual freshwater withdrawals, total (billion c...                                          -0.152970
# Cereal yield (kg per hectare)                                                               -0.295003
# Control of Corruption: Estimate                                                             -0.220109
# Electricity production from hydroelectric sourc...                                           1.000000
# Permanent cropland (% of land area)                                                         -0.207267
# Population density (people per sq. km of land a...                                          -0.351871
#
#                                                     Permanent cropland (% of land area)  \
# Year                                                                           0.020454
# Level of water stress: freshwater withdrawal as...                            -0.085238
# Annual freshwater withdrawals, agriculture (% o...                             0.113202
# Annual freshwater withdrawals, industry (% of t...                            -0.127054
# Annual freshwater withdrawals, domestic (% of t...                            -0.034167
# Renewable internal freshwater resources per cap...                            -0.144745
# Urban population (% of total population)                                      -0.185562
# State capacity estimate                                                       -0.137571
# Cattle Production                                                             -0.104887
# Annual freshwater withdrawals, total (billion c...                            -0.008504
# Cereal yield (kg per hectare)                                                 -0.086527
# Control of Corruption: Estimate                                               -0.147713
# Electricity production from hydroelectric sourc...                            -0.207267
# Permanent cropland (% of land area)                                            1.000000
# Population density (people per sq. km of land a...                             0.052391
#
#                                                     Population density (people per sq. km of land area)
# Year                                                                                         0.020145
# Level of water stress: freshwater withdrawal as...                                           0.060092
# Annual freshwater withdrawals, agriculture (% o...                                          -0.145916
# Annual freshwater withdrawals, industry (% of t...                                           0.104309
# Annual freshwater withdrawals, domestic (% of t...                                           0.108866
# Renewable internal freshwater resources per cap...                                          -0.090851
# Urban population (% of total population)                                                     0.173087
# State capacity estimate                                                                      0.122687
# Cattle Production                                                                           -0.045118
# Annual freshwater withdrawals, total (billion c...                                           0.007717
# Cereal yield (kg per hectare)                                                                0.215995
# Control of Corruption: Estimate                                                              0.211179
# Electricity production from hydroelectric sourc...                                          -0.351871
# Permanent cropland (% of land area)                                                          0.052391
# Population density (people per sq. km of land a...                                           1.000000

# %%
df_final.rename(columns = {'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources (%)':'stress',
                           'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)':'% agriculture water',
                           'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)':'% industry water',
                           'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)':'% domestic water',
                           'Renewable internal freshwater resources per capita (cubic meters)':'water resources water per capita',
                           'Urban population (% of total population)':'% urban population',
                           'Annual freshwater withdrawals, total (billion cubic meters)':'total withdrawals',
                           'Cereal yield (kg per hectare)':'cereal yield',
                           'Control of Corruption: Estimate':'control of corruption',
                           'Electricity production from hydroelectric sources (% of total)':'% hydro electricity',
                           'Permanent cropland (% of land area)':'% permanent cropland',
                           'Population density (people per sq. km of land area)':'population density',
                           'State capacity estimate':'state capacity',
                           'Cattle Production':'cattle',
                           'Entity':'country',
                           'Code':'code',
                           'Year':'year'
                           }, inplace = True)
df_final
# Out:
#           country code  year  stress  % agriculture water  % industry water  \
# 0     Afghanistan  AFG  2000   54.76            98.606200          0.633545
# 1     Afghanistan  AFG  2001   54.76            98.518580          0.673374
# 2     Afghanistan  AFG  2002   54.76            98.431110          0.713133
# 3     Afghanistan  AFG  2003   54.76            98.343796          0.752822
# 4     Afghanistan  AFG  2004   54.76            98.256630          0.792440
# ...           ...  ...   ...     ...                  ...               ...
# 2391     Zimbabwe  ZWE  2011   32.70            80.580560          4.255136
# 2392     Zimbabwe  ZWE  2012   32.49            80.195750          3.799411
# 2393     Zimbabwe  ZWE  2013   32.28            79.806060          3.337913
# 2394     Zimbabwe  ZWE  2014   32.08            79.411410          2.870530
# 2395     Zimbabwe  ZWE  2015   31.87            79.011690          2.397149
#
#       % domestic water  water resources water per capita  % urban population  \
# 0             0.760254                         2412.6309              22.078
# 1             0.808049                         2394.7830              22.169
# 2             0.855760                         2245.2107              22.261
# 3             0.903386                         2082.1255              22.353
# 4             0.950928                         2001.8213              22.500
# ...                ...                               ...                 ...
# 2391         15.164305                          941.2101              33.015
# 2392         16.004839                          924.2136              32.834
# 2393         16.856024                          904.4351              32.654
# 2394         17.718060                          884.8310              32.504
# 2395         18.591160                          866.1289              32.385
#
#       state capacity      cattle  total withdrawals  cereal yield  \
# 0           -1.18400   700000.00          20.282000         806.3
# 1           -1.28100   600000.00          20.282000        1006.7
# 2           -1.33200   833000.00          20.282000        1669.8
# 3           -1.80300   761000.00          20.282000        1458.0
# 4           -1.82600   829000.00          20.282000        1334.8
# ...              ...         ...                ...           ...
# 2391         0.03609  3060942.49           3.482850         587.4
# 2392         0.08874  3069409.87           3.460625         695.7
# 2393         0.05633  3072585.53           3.438750         668.5
# 2394         0.26540  2500000.00           3.416875         831.4
# 2395         0.29650  2600000.00           3.395000         557.5
#
#       control of corruption  % hydro electricity  % permanent cropland  \
# 0                 -1.271724                  NaN              0.170185
# 1                       NaN                  NaN              0.171719
# 2                 -1.251137                  NaN              0.171719
# 3                 -1.344180                  NaN              0.171719
# 4                 -1.350647                  NaN              0.171719
# ...                     ...                  ...                   ...
# 2391              -1.425627            56.434462              0.258498
# 2392              -1.381803            58.567858              0.258498
# 2393              -1.419667            52.204807              0.258498
# 2394              -1.404367            54.169160              0.258498
# 2395              -1.337617            51.395612              0.258498
#
#       population density
# 0              29.963329
# 1              30.186640
# 2              32.197624
# 3              34.719547
# 4              36.112339
# ...                  ...
# 2391           33.671410
# 2392           34.290632
# 2393           35.040512
# 2394           35.816862
# 2395           36.590247
#
# [2396 rows x 17 columns]

# %%
df_final.columns
# Out:
# Index(['country', 'code', 'year', 'stress', '% agriculture water',
#        '% industry water', '% domestic water',
#        'water resources water per capita', '% urban population',
#        'state capacity', 'cattle', 'total withdrawals', 'cereal yield',
#        'control of corruption', '% hydro electricity', '% permanent cropland',
#        'population density'],
#       dtype='object')

# %%
df_copy = df_final.copy()

# Initialize KNNImputer with desired parameters
imputer = KNNImputer(n_neighbors = 4)  # You can adjust the number of neighbors as needed

# Impute NaN values using KNNImputer
df_copy[['total withdrawals',
         'cereal yield',
         'control of corruption',
         '% hydro electricity',
         '% permanent cropland',
         'population density'
         ]] = imputer.fit_transform(df_copy[['total withdrawals',
                                             'cereal yield',
                                             'control of corruption',
                                             '% hydro electricity',
                                             '% permanent cropland',
                                             'population density'
                                             ]])

# %%
df_copy
# Out:
#           country code  year  stress  % agriculture water  % industry water  \
# 0     Afghanistan  AFG  2000   54.76            98.606200          0.633545
# 1     Afghanistan  AFG  2001   54.76            98.518580          0.673374
# 2     Afghanistan  AFG  2002   54.76            98.431110          0.713133
# 3     Afghanistan  AFG  2003   54.76            98.343796          0.752822
# 4     Afghanistan  AFG  2004   54.76            98.256630          0.792440
# ...           ...  ...   ...     ...                  ...               ...
# 2391     Zimbabwe  ZWE  2011   32.70            80.580560          4.255136
# 2392     Zimbabwe  ZWE  2012   32.49            80.195750          3.799411
# 2393     Zimbabwe  ZWE  2013   32.28            79.806060          3.337913
# 2394     Zimbabwe  ZWE  2014   32.08            79.411410          2.870530
# 2395     Zimbabwe  ZWE  2015   31.87            79.011690          2.397149
#
#       % domestic water  water resources water per capita  % urban population  \
# 0             0.760254                         2412.6309              22.078
# 1             0.808049                         2394.7830              22.169
# 2             0.855760                         2245.2107              22.261
# 3             0.903386                         2082.1255              22.353
# 4             0.950928                         2001.8213              22.500
# ...                ...                               ...                 ...
# 2391         15.164305                          941.2101              33.015
# 2392         16.004839                          924.2136              32.834
# 2393         16.856024                          904.4351              32.654
# 2394         17.718060                          884.8310              32.504
# 2395         18.591160                          866.1289              32.385
#
#       state capacity      cattle  total withdrawals  cereal yield  \
# 0           -1.18400   700000.00          20.282000         806.3
# 1           -1.28100   600000.00          20.282000        1006.7
# 2           -1.33200   833000.00          20.282000        1669.8
# 3           -1.80300   761000.00          20.282000        1458.0
# 4           -1.82600   829000.00          20.282000        1334.8
# ...              ...         ...                ...           ...
# 2391         0.03609  3060942.49           3.482850         587.4
# 2392         0.08874  3069409.87           3.460625         695.7
# 2393         0.05633  3072585.53           3.438750         668.5
# 2394         0.26540  2500000.00           3.416875         831.4
# 2395         0.29650  2600000.00           3.395000         557.5
#
#       control of corruption  % hydro electricity  % permanent cropland  \
# 0                 -1.271724            77.261952              0.170185
# 1                 -1.361446            32.032413              0.171719
# 2                 -1.251137            60.789356              0.171719
# 3                 -1.344180            36.992243              0.171719
# 4                 -1.350647            50.311936              0.171719
# ...                     ...                  ...                   ...
# 2391              -1.425627            56.434462              0.258498
# 2392              -1.381803            58.567858              0.258498
# 2393              -1.419667            52.204807              0.258498
# 2394              -1.404367            54.169160              0.258498
# 2395              -1.337617            51.395612              0.258498
#
#       population density
# 0              29.963329
# 1              30.186640
# 2              32.197624
# 3              34.719547
# 4              36.112339
# ...                  ...
# 2391           33.671410
# 2392           34.290632
# 2393           35.040512
# 2394           35.816862
# 2395           36.590247
#
# [2396 rows x 17 columns]
